# %%
import matplotlib.pyplot as plt

# %%
x = [0,1,2,3]
y = [0,1,2,3]
p = [1,2,4,4]
plt.plot(x,y, marker = 'X', color = 'r')

plt.plot(p,x, marker = 'o', color = 'g')
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Test Line Graph")
plt.show()

# %%
months = ["Jan", "Feb", "March"]
sales = [3,2,1]
plt.barh(months, sales, color='g')
plt.show()

# %%
pwd
# Out:
# 'C:\\Users\\anage\\Documents\\Python_Practice'

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\anage\\Documents\\DS\\Kaggle datasets\\Salary_dataset.csv", usecols = ["YearsExperience","Salary"])

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
values = [10,20,30,10,20,20,20,20,30,30,30,10,10,40]
plt.hist(values, bins = 15)
plt.show()

# %%
plt.bar(df.YearsExperience, df.Salary, height = 1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 plt.bar(df.YearsExperience, df.Salary, height = 1)
#       2 plt.show()
#
# TypeError: bar() got multiple values for argument 'height'

# %%
brands = ["Samsung","IPhone","Redmi","Vivo"]
sales = [30,20,10,20]

plt.pie(sales, labels= brands)
plt.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt

data = [10,20,250,30,40,50,90]
plt.boxplot(data)
plt.show()
