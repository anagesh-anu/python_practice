# %%
pwd
# Out:
# 'C:\\Users\\anage\\Documents\\Python_Practice'

# %%
import pandas as pd

# %%
ipl_df = pd.read_csv("C:\\Users\\anage\\Documents\\DS\\Kaggle datasets\\deliveries.csv")

# %%
ipl_df.head(2)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN

# %%
ipl_df.shape
# Out:
# (260920, 17)

# %%
ipl_df.describe()
# Out:
#            match_id         inning           over           ball  \
# count  2.609200e+05  260920.000000  260920.000000  260920.000000
# mean   9.070665e+05       1.483531       9.197677       3.624486
# std    3.679913e+05       0.502643       5.683484       1.814920
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.483340e+05       1.000000       4.000000       2.000000
# 50%    9.809670e+05       1.000000       9.000000       4.000000
# 75%    1.254066e+06       2.000000      14.000000       5.000000
# max    1.426312e+06       6.000000      19.000000      11.000000
#
#         batsman_runs     extra_runs     total_runs      is_wicket
# count  260920.000000  260920.000000  260920.000000  260920.000000
# mean        1.265001       0.067806       1.332807       0.049632
# std         1.639298       0.343265       1.626416       0.217184
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
ipl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
# ...

# %%
mask_over = ((ipl_df['over']==19) & (ipl_df['batting_team'] == 'Chennai Super Kings'))
csk = ipl_df[mask_over]

# %%
csk.iloc[:]
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 343       335983       1  Chennai Super Kings              Kings XI Punjab
# 344       335983       1  Chennai Super Kings              Kings XI Punjab
# 345       335983       1  Chennai Super Kings              Kings XI Punjab
# 346       335983       1  Chennai Super Kings              Kings XI Punjab
# 347       335983       1  Chennai Super Kings              Kings XI Punjab
# ...          ...     ...                  ...                          ...
# 259784   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
# 259785   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
# 259786   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
# 259787   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
# 259788   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
#
# ...

# %%
csk_over
# Out:
# 343       6
# 344       6
# 345       4
# 346       1
# 347       6
#          ..
# 259784    0
# 259785    0
# 259786    1
# 259787    0
# 259788    0
# Name: total_runs, Length: 1165, dtype: int64

# %%
csk_over = csk_over['total_runs']

# %%
csk_over.sum()
# Out:
# 2282

# %%
csk_over.shape
# Out:
# (1165,)

# %%
ipl_df[ipl_df['batter'].str.contains('Dhoni')]
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 265       335983       1  Chennai Super Kings              Kings XI Punjab
# 268       335983       1  Chennai Super Kings              Kings XI Punjab
# 269       335983       1  Chennai Super Kings              Kings XI Punjab
# 1719      335989       1  Chennai Super Kings               Mumbai Indians
# 1720      335989       1  Chennai Super Kings               Mumbai Indians
# ...          ...     ...                  ...                          ...
# 259777   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
# 259780   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
# 259781   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
# 259783   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
# 259784   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
#
# ...

# %%
import pandas as pd

# %%
ll = [1,2,4,5,5,6]
s= pd.Series(ll)
print(dir(s))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__bool__', '__class__', '__column_consortium_standard__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__r
# ...

# %%
df2 = pd.read_csv('real_estate_price.csv', names=['size', 'price'])
df2 = df2.rename(columns=str.upper)
# Out:
#     SIZE  PRICE
# 0   1200   2500
# 1   1201   2501
# 2   1202   2502
# 3   1203   2503
# 4   1204   2504
# ..   ...    ...
# 94  1294   2594
# 95  1295   2595
# 96  1296   2596
# 97  1297   2597
# 98  1298   2598
#
# [99 rows x 2 columns]

# %%
df2['city'] = 'Nan'

# %%
df2.iloc[80,2] = 'Bangalore'

# %%
df2['city'].unique()
# Out:
# array(['Hyderabad', 'Chennai', 'Mumbai', 'Pune', 'Bangalore'],
#       dtype=object)

# %%
df2
# Out:
#     SIZE  PRICE       city  price_sqft
# 0   1200   2500  Hyderabad    2.083333
# 1   1201   2501  Hyderabad    2.082431
# 2   1202   2502  Hyderabad    2.081531
# 3   1203   2503  Hyderabad    2.080632
# 4   1204   2504  Hyderabad    2.079734
# ..   ...    ...        ...         ...
# 94  1294   2594  Bangalore    2.004637
# 95  1295   2595  Bangalore    2.003861
# 96  1296   2596  Bangalore    2.003086
# 97  1297   2597  Bangalore    2.002313
# 98  1298   2598  Bangalore    2.001541
#
# [99 rows x 4 columns]

# %%
df2['sub-location'] = 'Nan'

# %%
#df2.to_csv("real_estate.csv")
df2 = pd.read_csv("real_estate.csv")

# %%
df2['Sub-Location'].fillna( method ='ffill', inplace = True)
# Out:
# C:\Users\anage\AppData\Local\Temp\ipykernel_9828\3895568672.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2['Sub-Location'].fillna( method ='ffill', inplace = True)

# %%
df2[df2['Sub-Location'] == "None"]
# Out:
#     Unnamed: 0  Size  Price       City  Price_Sqft Sub-Location  Metro-Index  \
# 5            5  1205   2505  Hyderabad    2.078838         None            2
# 6            6  1206   2506  Hyderabad    2.077944         None            2
# 19          19  1219   2519  Hyderabad    2.066448         None            1
# 32          32  1232   2532    Chennai    2.055195         None            1
# 51          51  1251   2551     Mumbai    2.039169         None            2
#
#     Gated Societies
# 5                 2
# 6                 1
# 19                3
# 32                8
# 51                2

# %%
df2.head(10)
# Out:
#    Unnamed: 0  Size  Price       City  Price_Sqft Sub-Location  Metro-Index  \
# 0           0  1200   2500  Hyderabad    2.083333     Ameerpet            2
# 1           1  1201   2501  Hyderabad    2.082431     Ameerpet            2
# 2           2  1202   2502  Hyderabad    2.081531     Ameerpet            2
# 3           3  1203   2503  Hyderabad    2.080632     Ameerpet            2
# 4           4  1204   2504  Hyderabad    2.079734     Ameerpet            2
# 5           5  1205   2505  Hyderabad    2.078838         None            2
# 6           6  1206   2506  Hyderabad    2.077944         None            2
# 7           7  1207   2507  Hyderabad    2.077051      Miyapur            2
# 8           8  1208   2508  Hyderabad    2.076159      Miyapur            2
# 9           9  1209   2509  Hyderabad    2.075269      Miyapur            2
#
#    Gated Societies
# 0                3
# 1                5
# 2                3
# 3                2
# 4                5
# ...

# %%
df2[df2['city']== 'Bangalore'].head(25)
# Out:
#     SIZE  PRICE       city  price_sqft sub-location
# 80  1280   2580  Bangalore    2.015625          Nan
# 81  1281   2581  Bangalore    2.014832          Nan
# 82  1282   2582  Bangalore    2.014041          Nan
# 83  1283   2583  Bangalore    2.013250          Nan
# 84  1284   2584  Bangalore    2.012461          Nan
# 85  1285   2585  Bangalore    2.011673          Nan
# 86  1286   2586  Bangalore    2.010886          Nan
# 87  1287   2587  Bangalore    2.010101          Nan
# 88  1288   2588  Bangalore    2.009317          Nan
# 89  1289   2589  Bangalore    2.008534          Nan
# 90  1290   2590  Bangalore    2.007752          Nan
# 91  1291   2591  Bangalore    2.006971          Nan
# 92  1292   2592  Bangalore    2.006192          Nan
# 93  1293   2593  Bangalore    2.005414          Nan
# 94  1294   2594  Bangalore    2.004637          Nan
# 95  1295   2595  Bangalore    2.003861          Nan
# 96  1296   2596  Bangalore    2.003086          Nan
# ...

# %%
df2.iloc[36:41,4] = 'ECR'

# %%
df2.head(22)
# Out:
#     SIZE  PRICE       city  price_sqft sub-location
# 0   1200   2500  Hyderabad    2.083333     Ameerpet
# 1   1201   2501  Hyderabad    2.082431     Ameerpet
# 2   1202   2502  Hyderabad    2.081531     Ameerpet
# 3   1203   2503  Hyderabad    2.080632     Ameerpet
# 4   1204   2504  Hyderabad    2.079734     Ameerpet
# 5   1205   2505  Hyderabad    2.078838     Ameerpet
# 6   1206   2506  Hyderabad    2.077944      Miyapur
# 7   1207   2507  Hyderabad    2.077051      Miyapur
# 8   1208   2508  Hyderabad    2.076159      Miyapur
# 9   1209   2509  Hyderabad    2.075269      Miyapur
# 10  1210   2510  Hyderabad    2.074380      Miyapur
# 11  1211   2511  Hyderabad    2.073493    Khajaguda
# 12  1212   2512  Hyderabad    2.072607    Khajaguda
# 13  1213   2513  Hyderabad    2.071723    Khajaguda
# 14  1214   2514  Hyderabad    2.070840    Khajaguda
# 15  1215   2515  Hyderabad    2.069959    Khajaguda
# 16  1216   2516  Hyderabad    2.069079   Gachibowli
# ...

# %%
gb = df2.groupby('city').first()

# %%
gb
# Out:
#            SIZE  PRICE  price_sqft
# city
# Bangalore  1280   2580    2.015625
# Chennai    1221   2521    2.064701
# Hyderabad  1200   2500    2.083333
# Mumbai     1241   2541    2.047542
# Pune       1260   2560    2.031746

# %%
df2 =pd.read_csv("test.csv")

# %%
df2
# Out:
#     Unnamed: 0  SIZE  PRICE       city  price_sqft  sub-location  metro-index  \
# 0            0  1200   2500  Hyderabad    2.083333      Ameerpet            2
# 1            1  1201   2501  Hyderabad    2.082431      Ameerpet            2
# 2            2  1202   2502  Hyderabad    2.081531      Ameerpet            2
# 3            3  1203   2503  Hyderabad    2.080632      Ameerpet            2
# 4            4  1204   2504  Hyderabad    2.079734      Ameerpet            2
# ..         ...   ...    ...        ...         ...           ...          ...
# 94          94  1294   2594  Bangalore    2.004637  White Fields            2
# 95          95  1295   2595  Bangalore    2.003861  Rajaji Nagar            3
# 96          96  1296   2596  Bangalore    2.003086  Rajaji Nagar            3
# 97          97  1297   2597  Bangalore    2.002313  Rajaji Nagar            3
# 98          98  1298   2598  Bangalore    2.001541  Rajaji Nagar            3
#
#     gated societies
# ...

# %%
df2.groupby(['city', 'sub-location']).count()
# Out:
#                            Unnamed: 0  SIZE  PRICE  price_sqft  metro-index  \
# city      sub-location
# Bangalore Bus Stand                 5     5      5           5            5
#           Railway Station           5     5      5           5            5
#           Rajaji Nagar              4     4      4           4            4
#           White Fields              5     5      5           5            5
# Chennai   Adayar                    5     5      5           5            5
#           ECR                       5     5      5           5            5
#           Mambalam                  5     5      5           5            5
#           Tambaram                  5     5      5           5            5
# Hyderabad Ameerpet                  6     6      6           6            6
#           Gachibowli                5     5      5           5            5
#           Khajaguda                 5     5      5           5            5
# ...

# %%
pt = df2.pivot_table(index= 'city', columns= 'sub-location', aggfunc = 'count')

# %%
import seaborn as sns

# %%
sns.heatmap(pt)
# Out:
# <Axes: xlabel='None-sub-location', ylabel='city'>

# %%
s = pd.Series({'A':1, 'B':2})
print(s)
# Out:
# A    1
# B    2
# dtype: int64

# %%
a = [10,20,30,40]
i = ['a','b1','c','b1']

s = pd.Series(a, index = ['ak','al','k','l'])

print(s)
# Out:
# ak    10
# al    20
# k     30
# l     40
# dtype: int64

# %%
import pandas as pd
inde = [1,2,3,4,5,6,7]
s= pd.Series(range(7), index = inde, name = 'test')
s
# Out:
# 1    0
# 2    1
# 3    2
# 4    3
# 5    4
# 6    5
# 7    6
# Name: test, dtype: int64

# %%
dff = pd.DataFrame(
    {
        "Name": ["A","B","C","D"],
        "Age":[21,22,23,21]
    }
)
dff
# Out:
#   Name  Age
# 0    A   21
# 1    B   22
# 2    C   23
# 3    D   21

# %%
df2.head(1)
# Out:
#    Unnamed: 0  SIZE  PRICE       city  price_sqft sub-location  metro-index  \
# 0           0  1200   2500  Hyderabad    2.083333     Ameerpet            2
#
#    gated societies
# 0                3

# %%
df2.columns
# Out:
# Index(['SIZE', 'PRICE', 'city', 'price_sqft', 'sub-location', 'metro-index',
#        'gated societies'],
#       dtype='object')

# %%
df2.loc[[1,2]]
# Out:
#    Unnamed: 0  SIZE  PRICE       city  price_sqft sub-location  metro-index  \
# 1           1  1201   2501  Hyderabad    2.082431     Ameerpet            2
# 2           2  1202   2502  Hyderabad    2.081531     Ameerpet            2
#
#    gated societies
# 1                5
# 2                3

# %%
l1 = ["a","b","c","d","e","f"]
s1 = pd.Series(l1)
print(s1)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# 5    f
# dtype: object

# %%
s1[1:3]
# Out:
# 1    b
# 2    c
# dtype: object

# %%
for i in s1: 
    print (i)
# Out:
# a
# b
# c
# d
# e
# f

# %%
print(s1.dtype)
# Out:
# object

# %%
dir(s1)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
ll2 = ['a','b','c','d']
s2 = pd.Series(ll2, index=["1","2","3","4"], name = 'test')
s2.str.
# Out:
# 1    A
# 2    B
# 3    C
# 4    D
# Name: test, dtype: object

# %%
s2
# Out:
# 1    a
# 2    b
# 3    c
# 4    d
# Name: test, dtype: object

# %%
dir(df2)
# Out:
# ['PRICE',
#  'SIZE',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
# ...

# %%
#df2.groupby(['city', 'sub-location']).count()
#df2.columns
#df2.drop(0, axis = 1, inplace = True)
#df2.rename(index = {0:'A',1:'B'}, columns = {'SIZE':'size','PRICE':'price'})
# Out:
#     size  price       city  price_sqft  sub-location  metro-index  \
# A   1200   2500  Hyderabad    2.083333      Ameerpet            2
# B   1201   2501  Hyderabad    2.082431      Ameerpet            2
# 2   1202   2502  Hyderabad    2.081531      Ameerpet            2
# 3   1203   2503  Hyderabad    2.080632      Ameerpet            2
# 4   1204   2504  Hyderabad    2.079734      Ameerpet            2
# ..   ...    ...        ...         ...           ...          ...
# 94  1294   2594  Bangalore    2.004637  White Fields            2
# 95  1295   2595  Bangalore    2.003861  Rajaji Nagar            3
# 96  1296   2596  Bangalore    2.003086  Rajaji Nagar            3
# 97  1297   2597  Bangalore    2.002313  Rajaji Nagar            3
# 98  1298   2598  Bangalore    2.001541  Rajaji Nagar            3
#
#     gated societies
# A                 3
# B                 5
# 2                 3
# 3                 2
# 4                 5
# ..              ...
# 94                2
# ...

# %%
df2.columns.str.upper()
# Out:
# Index(['SIZE', 'PRICE', 'CITY', 'PRICE_SQFT', 'SUB-LOCATION', 'METRO-INDEX',
#        'GATED SOCIETIES'],
#       dtype='object')

# %%
df2.rename( columns={'Unnamed: 0':'Ind'}, inplace=True )

# %%
df2.add_prefix('col_', axis = 0)
# Out:
#         SIZE  PRICE       city  price_sqft  sub-location  metro-index  \
# col_0   1200   2500  Hyderabad    2.083333      Ameerpet            2
# col_1   1201   2501  Hyderabad    2.082431      Ameerpet            2
# col_2   1202   2502  Hyderabad    2.081531      Ameerpet            2
# col_3   1203   2503  Hyderabad    2.080632      Ameerpet            2
# col_4   1204   2504  Hyderabad    2.079734      Ameerpet            2
# ...      ...    ...        ...         ...           ...          ...
# col_94  1294   2594  Bangalore    2.004637  White Fields            2
# col_95  1295   2595  Bangalore    2.003861  Rajaji Nagar            3
# col_96  1296   2596  Bangalore    2.003086  Rajaji Nagar            3
# col_97  1297   2597  Bangalore    2.002313  Rajaji Nagar            3
# col_98  1298   2598  Bangalore    2.001541  Rajaji Nagar            3
#
#         gated societies
# col_0                 3
# col_1                 5
# col_2                 3
# col_3                 2
# ...

# %%
df2.head(1)
# Out:
#    SIZE  PRICE       city  price_sqft sub-location  metro-index  \
# 0  1200   2500  Hyderabad    2.083333     Ameerpet            2
#
#    gated societies
# 0                3

# %%
df2.set_axis(['size', 'price'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[643], line 1
# ----> 1 df2.set_axis(['size', 'price'], axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5357, in DataFrame.set_axis(self, labels, axis, copy)
#    5319 @Appender(
#    5320     """
#    5321     Examples
#    (...)
#    5355     copy: bool | None = None,
#    5356 ) -> DataFrame:
# -> 5357     return super().set_axis(labels, axis=axis, copy=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:792, in NDFrame.set_axis(self, labels, axis, copy)
#     746 def set_axis(
#     747     self,
#     748     labels,
#    (...)
#     751     copy: bool_t | None = None,
#     752 ) -> Self:
#     753     """
#     754     Assign desired index to given axis.
#     755
#    (...)
#     790     %(klass)s.rename_axis : Alter the name of the index%(see_also_sub)s.
#     791     """
# ...

# %%
df2.drop()
# Out:
#     SIZE  PRICE       city  price_sqft  sub-location  metro-index  \
# 0   1200   2500  Hyderabad    2.083333      Ameerpet            2
# 1   1201   2501  Hyderabad    2.082431      Ameerpet            2
# 2   1202   2502  Hyderabad    2.081531      Ameerpet            2
# 3   1203   2503  Hyderabad    2.080632      Ameerpet            2
# 4   1204   2504  Hyderabad    2.079734      Ameerpet            2
# ..   ...    ...        ...         ...           ...          ...
# 94  1294   2594  Bangalore    2.004637  White Fields            2
# 95  1295   2595  Bangalore    2.003861  Rajaji Nagar            3
# 96  1296   2596  Bangalore    2.003086  Rajaji Nagar            3
# 97  1297   2597  Bangalore    2.002313  Rajaji Nagar            3
# 98  1298   2598  Bangalore    2.001541  Rajaji Nagar            3
#
#     gated societies
# 0                 3
# 1                 5
# 2                 3
# 3                 2
# 4                 5
# ..              ...
# 94                2
# ...

# %%
df2['city'].unique()
# Out:
# array(['Hyderabad', 'Chennai', 'Mumbai', 'Pune', 'Bangalore'],
#       dtype=object)

# %%
df2.iloc[:,2:3]
# Out:
#          city
# 0   Hyderabad
# 1   Hyderabad
# 2   Hyderabad
# 3   Hyderabad
# 4   Hyderabad
# ..        ...
# 94  Bangalore
# 95  Bangalore
# 96  Bangalore
# 97  Bangalore
# 98  Bangalore
#
# [99 rows x 1 columns]

# %%
#df2.rename(columns={'SIZE':'size','PRICE':'price'})
df2.rename(index = {0:'a',1:'b'},
        columns= str.upper,
           inplace = True
          )

# %%
df2[df2.columns.values]
# Out:
#     SIZE  PRICE       CITY  PRICE_SQFT  SUB-LOCATION  METRO-INDEX  \
# a   1200   2500  Hyderabad    2.083333      Ameerpet            2
# b   1201   2501  Hyderabad    2.082431      Ameerpet            2
# 2   1202   2502  Hyderabad    2.081531      Ameerpet            2
# 3   1203   2503  Hyderabad    2.080632      Ameerpet            2
# 4   1204   2504  Hyderabad    2.079734      Ameerpet            2
# ..   ...    ...        ...         ...           ...          ...
# 94  1294   2594  Bangalore    2.004637  White Fields            2
# 95  1295   2595  Bangalore    2.003861  Rajaji Nagar            3
# 96  1296   2596  Bangalore    2.003086  Rajaji Nagar            3
# 97  1297   2597  Bangalore    2.002313  Rajaji Nagar            3
# 98  1298   2598  Bangalore    2.001541  Rajaji Nagar            3
#
#     GATED SOCIETIES
# a                 3
# b                 5
# 2                 3
# 3                 2
# 4                 5
# ..              ...
# 94                2
# ...

# %%
#df.loc[:, ['A', 'D']]
df2.loc[:4:2,::2]
#df2
# Out:
#    SIZE       CITY SUB-LOCATION  GATED SOCIETIES
# 0  1200  Hyderabad     Ameerpet                3
# 2  1202  Hyderabad     Ameerpet                3
# 4  1204  Hyderabad     Ameerpet                5

# %%
la = ['city', 'PRICE']
df2[la]
# Out:
#          city  PRICE
# 0   Hyderabad   2500
# 1   Hyderabad   2501
# 2   Hyderabad   2502
# 3   Hyderabad   2503
# 4   Hyderabad   2504
# ..        ...    ...
# 94  Bangalore   2594
# 95  Bangalore   2595
# 96  Bangalore   2596
# 97  Bangalore   2597
# 98  Bangalore   2598
#
# [99 rows x 2 columns]

# %%
df2.head(1)
# Out:
#    SIZE  PRICE       city  price_sqft sub-location  metro-index  \
# 0  1200   2500  Hyderabad    2.083333     Ameerpet            2
#
#    gated societies
# 0                3

# %%
df2.ix[0:4,4:]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9828\1269331646.py in ?()
# ----> 1 df2.ix[0:4,4:]
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
l3 = [1,4,5,3,4,5,6,7,88,874,99]
s3 = pd.Series(l3)
s3.describe()
# Out:
# count     11.000000
# mean      99.636364
# std      259.306102
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%       47.500000
# max      874.000000
# dtype: float64

# %%
s3[0:2]
# Out:
# 0    1
# 1    4
# dtype: int64

# %%
s3.describe()['25%']
# Out:
# 4.0

# %%
s3.dtype
# Out:
# dtype('int64')

# %%
df2.head(1)
# Out:
#    Size  Price       City  Price_Sqft Sub-Location  Metro-Index  \
# 0  1200   2500  Hyderabad    2.083333     Ameerpet            2
#
#    Gated Societies
# 0                3

# %%
#df2.columns[0:2]
df2.drop(df2.columns[0:2], axis=1)
# Out:
#          City  Price_Sqft  Sub-Location  Metro-Index  Gated Societies
# 0   Hyderabad    2.083333      Ameerpet            2                3
# 1   Hyderabad    2.082431      Ameerpet            2                5
# 2   Hyderabad    2.081531      Ameerpet            2                3
# 3   Hyderabad    2.080632      Ameerpet            2                2
# 4   Hyderabad    2.079734      Ameerpet            2                5
# ..        ...         ...           ...          ...              ...
# 94  Bangalore    2.004637  White Fields            2                2
# 95  Bangalore    2.003861  Rajaji Nagar            3                2
# 96  Bangalore    2.003086  Rajaji Nagar            3                2
# 97  Bangalore    2.002313  Rajaji Nagar            3                2
# 98  Bangalore    2.001541  Rajaji Nagar            3                2
#
# [99 rows x 5 columns]

# %%
df2.columns[[0, 2]]
# Out:
# Index(['Size', 'City'], dtype='object')

# %%
# dictionary with list object in values
details = {
    'Name' : ['Ankit', 'Aishwarya', 'Shaurya', 'Shivangi'],
    'Age' : [23, 21, 22, 21],
    'University' : ['BHU', 'JNU', 'DU', 'BHU'],
}
 
# creating a Dataframe object with skipping 
# one column i.e skipping age column.
#d = pd.DataFrame(details, columns = ['Name', 'University','Age'], index= ['a','b','c','d'])
d = pd.DataFrame(details)
d
# Out:
#         Name  Age University
# 0      Ankit   23        BHU
# 1  Aishwarya   21        JNU
# 2    Shaurya   22         DU
# 3   Shivangi   21        BHU

# %%
d['specialization'] = ['Msc', 'Bsc','Bsc','Msc']

# %%
d = d.assign(specialization = ['Msc', 'Bsc','Bsc','Msc'])

# %%
d
# Out:
#         Name  Age University specialization
# 0      Ankit   23        BHU            Msc
# 1  Aishwarya   21        JNU            Bsc
# 2    Shaurya   22         DU            Bsc
# 3   Shivangi   21        BHU            Msc

# %%
location = {'Ankit': 'NewYork', 'Aishwarya': 'Chicago', 
            'Shaurya': 'Boston', 'Shivangi': 'Miami'}

d['location'] = d['Name'].map(location)
# Out:
#         Name  Age University specialization location
# 0      Ankit   23        BHU            Msc  NewYork
# 1  Aishwarya   21        JNU            Bsc  Chicago
# 2    Shaurya   22         DU            Bsc   Boston
# 3   Shivangi   21        BHU            Msc    Miami

# %%
d['Name'].map(location)
# Out:
# 0    NewYork
# 1    Chicago
# 2     Boston
# 3      Miami
# Name: Name, dtype: object

# %%
d = d.assign(title = ['Mr','Ms','Mr','Mrs'])

# %%
marks = [70,90,85,65]
d= d.assign(Marks = marks)
d
# Out:
#         Name  Age University Specialization Location title ad_no  Marks
# 0      Ankit   23        BHU            Msc  NewYork    Mr   H21     70
# 1  Aishwarya   21        JNU            Bsc  Chicago    Ms   H22     90
# 2    Shaurya   22         DU            Bsc   Boston    Mr   H23     85
# 3   Shivangi   21        BHU            Msc    Miami   Mrs   H24     65

# %%
#d4 = pd.DataFrame({'Name':['Shaurya'], 
                    'Age': [22],
                    'University':['DU'],
                    'Specialization':['Bsc'],
                    'Location':['Boston'],
                    'title':['Mr'],
                    'ad_no':['H23'],
                    'Marks':[85]}
                    )
# Out:
#   Cell In[1291], line 2
#     'Age': [22],
#     ^
# IndentationError: unexpected indent

# %%
d = pd.concat([d, d4], ignore_index=True)

# %%
d.iloc[4,8] = 'Distinction'

# %%
d['Age'].value_counts()
# Out:
# Age
# 21    2
# 22    2
# 23    1
# Name: count, dtype: int64

# %%
d.iloc[4,1] = 23

# %%
d.sort_values(['Name','Age'])
# Out:
#         Name Age University Specialization Location title ad_no  Marks  \
# 1  Aishwarya  21        JNU            Bsc  Chicago    Ms   H22     90
# 0      Ankit  23        BHU            Msc  NewYork    Mr   H21     70
# 2    Shaurya  22         DU            Bsc   Boston    Mr   H23     85
# 4    Shaurya  23         DU            Bsc   Boston    Mr   H23     85
# 3   Shivangi  21        BHU            Msc    Miami   Mrs   H24     65
#
#   Result_Class
# 1  Distinction
# 0        First
# 2  Distinction
# 4  Distinction
# 3        First

# %%
d.groupby(['Specialization', 'University'])['Age'].mean()
# Out:
# Specialization  University
# Bsc             DU            22.5
#                 JNU           21.0
# Msc             BHU           22.0
# Name: Age, dtype: object

# %%
d.loc[d['Marks'] > 80, 'Result_Class'] = 'Distinction'
d.loc[d['Marks'] < 80, 'Result_Class'] = 'First'

# %%
#d[(d['Result_Class'] ==  'First') & (d['Location'] == 'Miami')]
d.loc[d['Result_Class'] == 'First', ['Name','Age']]
# Out:
#        Name  Age
# 0     Ankit   23
# 3  Shivangi   21

# %%
d.loc[len(d)] = ['Nagesh','24', 'ANU', 'Msc','LosAngeles','Mr','H26',95,'Distinction','Nan']

# %%
d.drop([5], axis = 1, inplace = True)

# %%
d
# Out:
#         Name Age University Specialization    Location title ad_no  Marks  \
# 0      Ankit  23        BHU            Msc     NewYork    Mr   H21     70
# 1  Aishwarya  21        JNU            Bsc     Chicago    Ms   H22     90
# 2    Shaurya  22         DU            Bsc      Boston    Mr   H23     85
# 3   Shivangi  21        BHU            Msc       Miami   Mrs   H24     65
# 4    Shaurya  23         DU            Bsc      Boston    Mr   H23     85
# 5     Nagesh  24        ANU            Msc  LosAngeles    Mr   H26     95
#
#   Result_Class
# 0        First
# 1  Distinction
# 2  Distinction
# 3        First
# 4  Distinction
# 5  Distinction

# %%
d.drop_duplicates(subset = ['Specialization', 'title'])
# Out:
#         Name Age University Specialization Location title ad_no  Marks  \
# 0      Ankit  23        BHU            Msc  NewYork    Mr   H21     70
# 1  Aishwarya  21        JNU            Bsc  Chicago    Ms   H22     90
# 2    Shaurya  22         DU            Bsc   Boston    Mr   H23     85
# 3   Shivangi  21        BHU            Msc    Miami   Mrs   H24     65
#
#   Result_Class    5
# 0        First  NaN
# 1  Distinction  NaN
# 2  Distinction  NaN
# 3        First  NaN

# %%
d['ad_no'] = adno

# %%
d.drop(['specialization'], axis = 1, inplace = True)

# %%
pwd
# Out:
# 'C:\\Users\\anage\\Documents\\Python_Practice'

# %%
dff = pd.read_csv("C:\\Users\\anage\\Documents\\DS\\Kaggle datasets\\deliveries.csv")

# %%
dff.head(1)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball      batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1  SC Ganguly  P Kumar  BB McCullum             0           1
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN

# %%
#### dff.groupby('batter')['total_runs'].sum().sort_values(ascending = False) 
dfd = pd.DataFrame(columns = ['batsman','average'])
def find_avg(batsman):
    tot_runs = dff[dff['batter'] == batsman]['total_runs'].sum()
    tot_balls = dff[dff['batter'] == batsman].shape[0]
    avgs = (tot_runs/tot_balls)*100
    #print(batsman , "---->" ,(tot_runs/tot_balls)*100)
    dfd.loc[len(dfd)] = [batsman,avgs]

larr = dff['batter'].unique()

for o in larr:
    find_avg(o)

dfd
# Out:
#               batsman     average
# 0          SC Ganguly  110.407240
# 1         BB McCullum  136.575704
# 2          RT Ponting   80.620155
# 3           DJ Hussey  125.703906
# 4     Mohammad Hafeez   82.142857
# ..                ...         ...
# 668        D Ferreira   72.727273
# 669          A Kamboj  100.000000
# 670  T Kohler-Cadmore   90.740741
# 671      Shivam Singh   66.666667
# 672      V Viyaskanth  140.000000
#
# [673 rows x 2 columns]

# %%
sb['A Ashish Reddy']
# Out:
# 196

# %%
gb = dff.groupby('total_runs')

# %%
gb.first()
# Out:
#             match_id  inning           batting_team  \
# total_runs
# 0             335982       1  Kolkata Knight Riders
# 1             335982       1  Kolkata Knight Riders
# 2             335982       1  Kolkata Knight Riders
# 3             335987       1        Kings XI Punjab
# 4             335982       1  Kolkata Knight Riders
# 5             335982       1  Kolkata Knight Riders
# 6             335982       1  Kolkata Knight Riders
# 7             335988       1        Deccan Chargers
#
#                            bowling_team  over  ball       batter      bowler  \
# total_runs
# 0           Royal Challengers Bangalore     0     2  BB McCullum     P Kumar
# 1           Royal Challengers Bangalore     0     1   SC Ganguly     P Kumar
# 2           Royal Challengers Bangalore     6     4   RT Ponting   AA Noffke
# 3                      Rajasthan Royals     7     3     JR Hopes  D Salunkhe
# 4           Royal Challengers Bangalore     1     2  BB McCullum      Z Khan
# ...

# %%
dff['bowling_team'].value_counts()
# Out:
# bowling_team
# Mumbai Indians                 31505
# Kolkata Knight Riders          29663
# Chennai Super Kings            28576
# Royal Challengers Bangalore    28358
# Rajasthan Royals               26432
# Kings XI Punjab                22483
# Sunrisers Hyderabad            21717
# Delhi Daredevils               18725
# Delhi Capitals                 11216
# Deccan Chargers                 9039
# Punjab Kings                    6719
# Pune Warriors                   5457
# Gujarat Titans                  5301
# Lucknow Super Giants            5226
# Gujarat Lions                   3545
# Rising Pune Supergiant          1928
# Royal Challengers Bengaluru     1801
# Rising Pune Supergiants         1615
# Kochi Tuskers Kerala            1614
# Name: count, dtype: int64

# %%
sl = pd.Series(['batting_team', 'bowling_team'])
sl
# Out:
# 0    batting_team
# 1    bowling_team
# dtype: object

# %%
dff.index
# Out:
# RangeIndex(start=0, stop=260920, step=1)

# %%
type(dxl)
# Out:
# pandas.core.frame.DataFrame

# %%
#dd = pd.read_html("https://en.wikipedia.org/wiki/The_World%27s_Billionaires")
#type(dd)
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
print(len(dd))
# Out:
# 48
